# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 【문항 1】 서울시 열린데이터 광장에서 자치구 년도별 CCTV 설치현황 자료를 다운로드 한 후 다음 프로그램을 작성하시오.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4116d56-6d05-459f-9fb0-78f8fa3aba7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4116d56-6d05-459f-9fb0-78f8fa3aba7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv to 서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv

# %% [markdown]
# ### 1. 데이터 파일 읽기

# %%
df = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv', skiprows=1, encoding='CP949')
df
# Out:
#       구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0      계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1    종로구   1,715      815    NaN    NaN    195    150      0     261      85
# 2    중 구   2,447       16    114     87     77    236    240     372     386
# 3    용산구   2,611       34     71    234    125    221    298     351     125
# 4    성동구   3,829      163    144    208    107    325    255     967     415
# 5    광진구   3,211       35     57    100    187     98     52     675     465
# 6   동대문구   2,628        4      0     14     16    115    804     814     201
# 7    중랑구   3,737      346     21    253     72    132    155     153     174
# 8    성북구   4,602       81     78    170    229    322    594     890     867
# 9    강북구   3,090        8      0     22     61    124    251      29     391
# 10   도봉구   1,930      128     22      2    145    172    123     129     222
# ...

# %% [markdown]
# ### 2. Null data 있는지 확인하고 0으로 대체하기

# %%
df = pd.DataFrame(df)
df = df.fillna(0)
df
# Out:
#       구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0      계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1    종로구   1,715      815      0      0    195    150      0     261      85
# 2    중 구   2,447       16    114     87     77    236    240     372     386
# 3    용산구   2,611       34     71    234    125    221    298     351     125
# 4    성동구   3,829      163    144    208    107    325    255     967     415
# 5    광진구   3,211       35     57    100    187     98     52     675     465
# 6   동대문구   2,628        4      0     14     16    115    804     814     201
# 7    중랑구   3,737      346     21    253     72    132    155     153     174
# 8    성북구   4,602       81     78    170    229    322    594     890     867
# 9    강북구   3,090        8      0     22     61    124    251      29     391
# 10   도봉구   1,930      128     22      2    145    172    123     129     222
# ...

# %% [markdown]
# ### 3. 1000 단위 구분기호 없애고 정수로 변환하기

# %%
df['총계'] = df['총계'].apply(lambda x: int(x.replace(',','')))
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '총계'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### 4. 2021년을 제외한 최근 3개년간의 CCTV 증가율 구하기

# %%
df.describe()
# Out:
#        구분,총계,2012년 이전,2012년,2013년,2014년,2015년,2016년,2017년,2018년,2019년,2020년,2021년
# count                                                  26
# unique                                                 26
# top     계,"83,557","4,812","1,851","3,434","4,295","6,...
# freq                                                    1

# %%
df.columns
# Out:
# Index(['구분,총계,2012년 이전,2012년,2013년,2014년,2015년,2016년,2017년,2018년,2019년,2020년,2021년'], dtype='object')

# %%
df.['2017년', '2018년', '2019년'].sum() / ['2021년']
# Out:
#   File "<ipython-input-36-13390e280171>", line 1
#     df.['2017년'].sum()
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 5. 구분, 총계, 최근증가율 컬럼만 추출하기

# %% [markdown]
# ### 6. 컬럼명을 구별, CCTV댓수로 변경하기

# %%
df.columns
# Out:
# Index(['구분,총계,2012년 이전,2012년,2013년,2014년,2015년,2016년,2017년,2018년,2019년,2020년,2021년'], dtype='object')

# %%
df.columns = ['구별', 'CCTV댓수']
df.columns

# %%
df.rename(columns={'구분':'구별'}, {'계':'CCTV댓수'}, inplace=True)
df
# Out:
#   File "<ipython-input-55-54e97123f57d>", line 1
#     df.rename(columns={'구분':'구별'}, {'계':'CCTV댓수'}, inplace=True)
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### 7. 구 이름에서 공백지우기

# %%
df['구분_strip'] = df['구분'].str.strip()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구분'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### 8. 첫 번째행(계) 지우기

# %%
df4 = df.drop(1, axis=0)
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-74de3c4f31d3> in <module>()
# ----> 1 df4 = df.drop(1, axis=0)
#       2 df4
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %% [markdown]
# # 【문항 2】서울시 통계서비스에서 주민등록인구(구별) 통계를 다운로드한 후 다음 프로그램을 작성하시오.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c04b59df-0a55-4fc1-a505-3250d195784c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c04b59df-0a55-4fc1-a505-3250d195784c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 서울시인구.txt to 서울시인구.txt

# %% [markdown]
# ### 1. 데이터 파일 읽기

# %%
df2 = pd.read_table('서울시인구.txt', skiprows=1, encoding='utf-8')
df2
# Out:
#       기간   자치구         세대         합계       합계.1       합계.2        한국인  \
# 0     기간   자치구         세대          계         남자         여자          계
# 1   2021    합계  4,426,007  9,736,027  4,721,977  5,014,050  9,509,458
# 2   2021   종로구     73,494    153,789     74,186     79,603    144,683
# 3   2021    중구     63,519    131,787     64,083     67,704    122,499
# 4   2021   용산구    111,036    237,285    115,085    122,200    222,953
# 5   2021   성동구    134,233    292,672    142,259    150,413    285,990
# 6   2021   광진구    167,949    352,627    169,317    183,310    339,996
# 7   2021  동대문구    168,219    352,006    172,162    179,844    337,400
# 8   2021   중랑구    185,712    391,885    192,903    198,982    387,350
# 9   2021   성북구    195,017    440,142    211,150    228,992    430,528
# 10  2021   강북구    144,536    302,563    146,984    155,579    299,182
# 11  2021   도봉구    138,656    319,373    155,221    164,152    317,366
# ...

# %% [markdown]
# ### 2. Null data 있는지 확인하기

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        27 non-null     object
#  1   자치구       27 non-null     object
#  2   세대        27 non-null     object
#  3   합계        27 non-null     object
#  4   합계.1      27 non-null     object
#  5   합계.2      27 non-null     object
#  6   한국인       27 non-null     object
#  7   한국인.1     27 non-null     object
#  8   한국인.2     27 non-null     object
#  9   등록외국인     27 non-null     object
#  10  등록외국인.1   27 non-null     object
#  11  등록외국인.2   27 non-null     object
#  12  세대당인구     27 non-null     object
#  13  65세이상고령자  27 non-null     object
# dtypes: object(14)
# memory usage: 3.1+ KB

# %%
df2.isnull()
# Out:
#        기간    자치구     세대     합계   합계.1   합계.2    한국인  한국인.1  한국인.2  등록외국인  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df2.isnull().sum()
# Out:
# 기간          0
# 자치구         0
# 세대          0
# 합계          0
# 합계.1        0
# 합계.2        0
# 한국인         0
# 한국인.1       0
# 한국인.2       0
# 등록외국인       0
# 등록외국인.1     0
# 등록외국인.2     0
# 세대당인구       0
# 65세이상고령자    0
# dtype: int64

# %% [markdown]
# ### 3. '자치구', '계', '계.1', '계.2', '65세이상고령자‘ 컬럼만 추출하기

# %%
df2 = df2[['자치구', '계', '합계1', '합계2', '65세이상고령자']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-6314ee9ea19d> in <module>()
# ----> 1 df2 = df2[['자치구', '계', '합계1', '합계2', '65세이상고령자']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %% [markdown]
# ### 4. 컬럼명을 '구별', '인구수', '내국인', '외국인', '고령자'로 변경하기

# %%
df2.columns
# Out:
# Index(['기간', '자치구', '세대', '합계', '합계.1', '합계.2', '한국인', '한국인.1', '한국인.2',
#        '등록외국인', '등록외국인.1', '등록외국인.2', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
df2.rename = (columns={'자치구':'구별'}, {'합계':'인구수'}, {'한국인':'내국인'}, {'등록외국인':'외국인'}, {'65세이상고령자':'고령자'}, inplace=True)
df2
# Out:
#   File "<ipython-input-68-9428d68ef598>", line 1
#     df2.rename = (columns={'자치구':'구별'}, {'합계':'인구수'}, {'한국인':'내국인'}, {'등록외국인':'외국인'}, {'65세이상고령자':'고령자'}, inplace=True)
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 5. 1000 단위 구분기호 없애고 정수로 변환하기

# %%
df2['총계'] = df['총계'].apply(lambda x: int(x.replace(',','')))
df2.head(3)

# %% [markdown]
# ### 6. 첫번째 행(합계행) 지우기

# %%
df2.shape
# Out:
# (27, 14)

# %%
df3 = df2.drop(1, axis=0)
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-bd6f25dda029> in <module>()
# ----> 1 df3 = df2.drop(1, axis=0)
#       2 df3
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %% [markdown]
# ### 7. '외국인비율‘과 '고령자비율‘ 컬럼 만들기

# %%
df2[['외국인비율', '고령자비율']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-44f9b590d4fa> in <module>()
# ----> 1 df2[['외국인비율', '고령자비율']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %% [markdown]
# ### 8. 구 이름에 공백이 있으면 공백지우기

# %%
df2['자치구_strip'] = df['자치구'].str.strip()
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '자치구'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%shell
# jupyter nbconvert --to html /content/drive/MyDrive/"Colab Notebooks"/u_미니프로젝트.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/u_미니프로젝트.ipynb to html
# [NbConvertApp] Writing 418850 bytes to /content/drive/MyDrive/Colab Notebooks/u_미니프로젝트.html
